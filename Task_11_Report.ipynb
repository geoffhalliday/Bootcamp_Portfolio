# %%
# Import pandas
import pandas as pd

# %%
# Create a DataFrame with balance.txt
df = pd.read_csv('balance.txt', delim_whitespace=True)
# Out:
# C:\Users\debbi\AppData\Local\Temp\ipykernel_6616\1558994609.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv('balance.txt', delim_whitespace=True)

# %% [markdown]
# Write the code needed to produce a report that provides the following information:
# * Compare the average income based on ethnicity.
# * On average, do married or single people have a higher balance?
# * What is the highest income in our dataset?
# * What is the lowest income in our dataset?
# * How many cards do we have recorded in our dataset? (Hint: use `sum()`)
# * How many females do we have information for vs how many males? (Hint: use `count()` for a list of all methods for computation of descriptive stats, explore the [pandas documentation](https://pandas.pydata.org/pandas-docs/stable/reference/frame.html#computations-descriptive-stats)).

# %% [markdown]
# REPORT 1: Average income based on ethnicity

# %%
print(df.groupby(['Ethnicity'])['Income'].mean())
# Out:
# Ethnicity
# African American    47.682101
# Asian               44.187833
# Caucasian           44.521945
# Name: Income, dtype: float64

# %% [markdown]
# REPORT 2: On average, do married or single people have a higher balance?

# %%
print("The average balance of a married person is", df[df.Married == "Yes"].loc[:,"Balance"].mean())
print("The average balance of a single person is",df[df.Married == "No"].loc[:,"Balance"].mean())
# Out:
# The average balance of a married person is 13.388473477498913
# The average balance of a single person is 13.493509015134242

# %% [markdown]
# REPORT 3: What is the highest income in our dataset?

# %%
print("The highest income in our dataset is",df['Income'].max())
# Out:
# The highest income in our dataset is 186.634

# %% [markdown]
# REPORT 4: What is the lowest income in our dataset?

# %%
print("The lowest income in our dataset is",df['Income'].min())
# Out:
# The lowest income in our dataset is 10.354

# %% [markdown]
# REPORT 5: How many cards do we have recorded in our dataset?

# %%
print("There are",df['Cards'].sum(),"cards recorded in the dataset")
# Out:
# There are 1183 cards recorded in the dataset

# %% [markdown]
# REPORT 6: How many females do we have information for vs how many males?

# %%
print("We have information for",df[df.Gender=="Female"].loc[:,'Gender'].count(),"females in the dataset")
print("We have infromation for",df[df.Gender=="Male"].loc[:,'Gender'].count(),"males in the dataset")
# Out:
# We have information for 207 females in the dataset
# We have infromation for 193 males in the dataset
